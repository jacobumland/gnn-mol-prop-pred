# %%
import pandas as pd

# %% [markdown]
# # experimentation results

# %% [markdown]
# ## performance

# %%
# load experimentation results overview 
overview_df = pd.read_parquet("models/experimentation_overview")
overview_df
# Out:
#      model_type                   filename        GPU_accelerator       RAM  \
# 0           SVM   svm_opt_full_descr_5k_50  Tesla P100-PCIE-16GB   27.33 GB
# 1           SVM  svm_opt_feat_select_5k_50  Tesla P100-PCIE-16GB   27.33 GB
# 2            RF       rf_opt_full_descr_50  Tesla P100-PCIE-16GB   27.33 GB
# 3            RF      rf_opt_feat_select_50  Tesla P100-PCIE-16GB   27.33 GB
# 4           XGB      xgb_opt_full_descr_50  Tesla P100-PCIE-16GB   27.33 GB
# 5           XGB     xgb_opt_feat_select_50  Tesla P100-PCIE-16GB   27.33 GB
# 6           MLP      mlp_opt_full_descr_50              Tesla T4   27.33 GB
# 7           MLP     mlp_opt_feat_select_50  Tesla P100-PCIE-16GB   27.33 GB
# 8           GCN                    gcn_opt  Tesla P100-PCIE-16GB   27.33 GB
# 9   AttentiveFP                  attfp_opt              Tesla T4   27.33 GB
# 10          GAT                    gat_opt  Tesla P100-PCIE-16GB   27.33 GB
# ...

# %% [markdown]
# ## computational efficiency

# %%
times_df = pd.read_parquet("models/models_avg_train_iter_times")
times_df
# Out:
#            model               data         GPU avg_train_iter_times
# 0            SVM    all descriptors  Tesla P100           259.78s/it
# 1            SVM  feature selection  Tesla P100            97.03s/it
# 2             RF    all descriptors  Tesla P100            59.38s/it
# 3             RF  feature selection  Tesla P100            17.46s/it
# 4            XGB    all descriptors  Tesla P100            50.46s/it
# 5            XGB  feature selection  Tesla P100            15.76s/it
# 6            MLP    all descriptors    Tesla T4           542.74s/it
# 7            MLP  feature selection  Tesla P100           595.14s/it
# 8            GCN             graphs  Tesla P100           610.66s/it
# 9            GAT             graphs  Tesla P100           755.30s/it
# 10          MPNN             graphs  Tesla P100          1831.57s/it
# 11  Attentive FP             graphs    Tesla T4          1220.09s/it
# 12         Weave             graphs  Tesla P100           970.50s/it
# ...
